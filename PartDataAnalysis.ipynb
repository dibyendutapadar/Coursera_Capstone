# %%
import pandas as pd
import numpy as np
import random as rnd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
partNoPath="E:\CarWorkz\DataUpdates\Data Analysis\db_workshop.PartNumber.csv"
db_partNo=pd.read_csv(partNoPath)
db_partNo.head()
# Out:
# C:\Users\23165948\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             brandId   fuelType   makeSlug  modelSlug partId   partNumber  \
# 0  1514390588002928  universal  universal  universal   C005  FFPRMFOL021
# 1  1514390588002928  universal  universal  universal   C005  FFPRMFOL010
# 2  1514390588002928     Diesel  universal  universal   C005  FFPRMFOL005
# 3  1514390588002928  universal  universal  universal   C006  FFPRMFOL018
# 4  1514390588002928  universal  universal  universal   C008  FFPRMFOL030
#
#   variantCode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
partRatePath="E:\CarWorkz\DataUpdates\Data Analysis\db_workshop.PartRate.csv"
db_partRate=pd.read_csv(partRatePath)
db_partRate.head()
# Out:
# C:\Users\23165948\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0,1,3,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   assemblyGroup.0 assemblyGroup.1           brandId category  \
# 0             NaN             NaN  1514390588002928      NaN
# 1             NaN             NaN  1514390588002928      NaN
# 2             NaN             NaN  1514390588002928      NaN
# 3             NaN             NaN  1514390588002928      NaN
# 4             NaN             NaN  1514390588002928      NaN
#
#                      description  isOEM partIds.0   partNumber    partableId  \
# 0                SN 5W-40 26 LTR    NaN      C005  FFPRMFOL021  1.514390e+15
# 1             SM/CF 5W-30 55 LTR    NaN      C005  FFPRMFOL010  1.514390e+15
# 2         CI4  SAE 15W40 210 LTR    NaN      C005  FFPRMFOL005  1.514390e+15
# ...

# %%
brandPath="E:\CarWorkz\DataUpdates\Data Analysis\db_workshop.Brand.csv"
db_brand=pd.read_csv(brandPath)
db_brand.head()
# Out:
#                 _id                 createdOn       name ownerType    status  \
# 0  1511956351366698  2017-11-29T11:52:31.366Z       MFCS    SYSTEM  INACTIVE
# 1  1511956351871119  2017-11-29T11:52:31.871Z  Purolator    SYSTEM    ACTIVE
# 2  1511956782289641  2017-11-29T11:59:42.289Z   Mahindra    SYSTEM    ACTIVE
# 3  1511956783212386  2017-11-29T11:59:43.212Z        NGK    SYSTEM    ACTIVE
# 4  1511956783419865  2017-11-29T11:59:43.419Z  Universal    SYSTEM    ACTIVE
#
#                   updatedOn vehicleType
# 0  2018-05-10T13:19:29.052Z        cars
# 1  2018-05-10T13:17:10.075Z        cars
# 2  2018-05-10T13:17:10.075Z        cars
# 3  2018-05-10T13:17:10.075Z        cars
# 4  2018-05-10T13:17:10.075Z        cars

# %%
db_partNo.replace(db_brand.set_index('_id').to_dict()['name'],inplace=True)

# %%
#db_partNo['brandName'] = db_partNo['brandId'].map(db_brand.set_index('_id').to_dict()['name'])
db_partNo.head()
# Out:
#   brandId   fuelType   makeSlug  modelSlug partId   partNumber variantCode
# 0     MFC  universal  universal  universal   C005  FFPRMFOL021         NaN
# 1     MFC  universal  universal  universal   C005  FFPRMFOL010         NaN
# 2     MFC     Diesel  universal  universal   C005  FFPRMFOL005         NaN
# 3     MFC  universal  universal  universal   C006  FFPRMFOL018         NaN
# 4     MFC  universal  universal  universal   C008  FFPRMFOL030         NaN

# %%
db_partRate['brandName'] = db_partRate['brandId'].map(db_brand.set_index('_id').to_dict()['name'])
db_partRate.head()
# Out:
#   assemblyGroup.0 assemblyGroup.1           brandId category  \
# 0             NaN             NaN  1514390588002928      NaN
# 1             NaN             NaN  1514390588002928      NaN
# 2             NaN             NaN  1514390588002928      NaN
# 3             NaN             NaN  1514390588002928      NaN
# 4             NaN             NaN  1514390588002928      NaN
#
#                      description  isOEM partIds.0   partNumber    partableId  \
# 0                SN 5W-40 26 LTR    NaN      C005  FFPRMFOL021  1.514390e+15
# 1             SM/CF 5W-30 55 LTR    NaN      C005  FFPRMFOL010  1.514390e+15
# 2         CI4  SAE 15W40 210 LTR    NaN      C005  FFPRMFOL005  1.514390e+15
# 3       GO GL-4 EP 80W90  26 LTR    NaN      C006  FFPRMFOL018  1.514390e+15
# 4  PRIVATE LABEL BRAKE OIL DOT 4  False      C008  FFPRMFOL030  1.514390e+15
#
#       partableType  purchasePrice  quantity  sellingPrice   type unit  \
# ...

# %%
db_partNo.columns
# Out:
# Index(['brandId', 'fuelType', 'makeSlug', 'modelSlug', 'partId', 'partNumber',
#        'variantCode'],
#       dtype='object')

# %%
db_partNo[["makeSlug","partNumber"]].groupby(["makeSlug"]).count()
# Out:
#                        partNumber
# makeSlug
# bikes-bajaj                  4223
# bikes-hero                  37805
# bikes-hero-honda             1268
# bikes-honda                 14767
# bikes-kawasaki-bajaj            2
# bikes-kinetic                   1
# bikes-mahindra               6231
# bikes-royal-enfield             4
# bikes-suzuki                   15
# bikes-tvs                    1638
# bikes-tvs-suzuki                3
# bikes-universal                13
# bikes-yamaha                   18
# cars-chevrolet                492
# cars-fiat                      30
# cars-ford                  683138
# cars-gm                       571
# cars-honda                    183
# cars-hyundai               767294
# cars-mahindra              339499
# cars-mahindra-renault       59913
# cars-maruti-suzuki         733984
# cars-nissan                 65990
# cars-renault               212548
# cars-skoda                    250
# cars-tata                  704673
# ...

# %%
db_partNo[["makeSlug","modelSlug","partNumber"]].groupby(["makeSlug","modelSlug"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartNobyModel.xlsx")

# %%
db_partNo[["makeSlug","modelSlug","variantCode"]].groupby(["makeSlug","modelSlug","variantCode"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\Variants.xlsx")

# %%
db_partRate.columns
# Out:
# Index(['assemblyGroup.0', 'assemblyGroup.1', 'brandId', 'category',
#        'description', 'isOEM', 'partIds.0', 'partNumber', 'partableId',
#        'partableType', 'purchasePrice', 'quantity', 'sellingPrice', 'type',
#        'unit', 'vehicleType', 'volume', 'brandName'],
#       dtype='object')

# %%
db_partRate["isPrice"]=1
db_partRate.head()
# Out:
#   assemblyGroup.0 assemblyGroup.1           brandId category  \
# 0             NaN             NaN  1514390588002928      NaN
# 1             NaN             NaN  1514390588002928      NaN
# 2             NaN             NaN  1514390588002928      NaN
# 3             NaN             NaN  1514390588002928      NaN
# 4             NaN             NaN  1514390588002928      NaN
#
#                      description  isOEM partIds.0   partNumber    partableId  \
# 0                SN 5W-40 26 LTR    NaN      C005  FFPRMFOL021  1.514390e+15
# 1             SM/CF 5W-30 55 LTR    NaN      C005  FFPRMFOL010  1.514390e+15
# 2         CI4  SAE 15W40 210 LTR    NaN      C005  FFPRMFOL005  1.514390e+15
# 3       GO GL-4 EP 80W90  26 LTR    NaN      C006  FFPRMFOL018  1.514390e+15
# 4  PRIVATE LABEL BRAKE OIL DOT 4  False      C008  FFPRMFOL030  1.514390e+15
#
#       partableType  purchasePrice  quantity  sellingPrice   type unit  \
# ...

# %%
db_partRate.loc[db_partRate['sellingPrice']==0,'isPrice']=0
# Out:
# assemblyGroup.0    163467
# assemblyGroup.1    163467
# brandId            191777
# category                0
# description        190960
# isOEM              191777
# partIds.0            5552
# partNumber         191776
# partableId              1
# partableType       191777
# purchasePrice      191777
# quantity           191777
# sellingPrice       191777
# type               125774
# unit               191776
# vehicleType        191777
# volume             191777
# brandName          191777
# isPrice            191777
# dtype: int64

# %%
db_partRate[["brandName","partNumber"]].groupby(["brandName"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartbyMake.xlsx")

# %%
db_partRate[(db_partRate["vehicleType"]=="bikes")][["brandName",'partNumber']].groupby(["brandName"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartbyMake.xlsx")

# %%
db_partRate[(db_partRate["vehicleType"]=="bikes")][["brandName",'partNumber','partIds.0']].groupby(["brandName"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartIds.xlsx")

# %%
db_partRate[(db_partRate["vehicleType"]=="bikes")][["brandName",'partNumber',"isPrice"]].groupby(["brandName","isPrice"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartPrice.xlsx")

# %%
db_partNo.groupby(["makeSlug","modelSlug","variantCode"]).count().to_excel("E:\CarWorkz\DataUpdates\Data Analysis\PartNumberAnalysis.xlsx")
